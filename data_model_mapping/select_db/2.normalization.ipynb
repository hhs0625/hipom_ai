# %%
import pandas as pd
import re

# Load the data_mapping CSV file
data_mapping_file_path = 'data_mapping.csv'  # Adjust this path to your actual file location
data_mapping = pd.read_csv(data_mapping_file_path, dtype=str)

# Initial replacement mapping
initial_replacements = {
    "MGE": "G/E",
    "GEN": "G/E",
    "GE": "G/E",
    "G_E": "G/E",
    "ME": "M/E",
    "M_E": "M/E",
    "S_G": "S/G",
    "T_C": "T/C",
    "TC": "T/C",
    "L_O": "L.O",
    "LO": "L.O",
    "F_O": "F.O",
    "FO": "F.O",
    "D_G": "D/G",
    "DG": "D/G"
}

# Second replacement mapping
second_replacements = {
    "_G/E": " G/E",
    "G/E_": "G/E ",
    "_M/E": " M/E",
    "M/E_": "M/E ",
    "_S/G": " S/G",
    "S/G_": "S/G ",
    "_T/C": " T/C",
    "T/C_": "T/C ",
    "_L.O": " L.O",
    "L.O_": "L.O ",
    "_F.O": " F.O",
    "F.O_": "F.O ",
    "_D/G": " D/G",
    "D/G_": "D/G ",
}

# Initialize counters
initial_replacement_counts = {key: 0 for key in initial_replacements}
second_replacement_counts = {key: 0 for key in second_replacements}

def replace_tokens_in_list(words, replacements, counts):
    for i, word in enumerate(words):
        if word in replacements:
            counts[word] += 1
            words[i] = replacements[word]
    return words

def replace_tokens_in_text(text, replacements, counts):
    if pd.isna(text):
        return text
    for old, new in replacements.items():
        # Count occurrences of the token
        count = text.count(old)
        counts[old] += count
        # Replace the token
        text = text.replace(old, new)
    return text

# Backup the original tag_description
data_mapping['org_tag_description'] = data_mapping['tag_description']

# Replace '(' and ')' with spaces
data_mapping['tag_description'] = data_mapping['tag_description'].apply(
    lambda x: x.replace('(', ' ').replace(')', ' ') if pd.notna(x) else x
)

# Function to tokenize and find tokens with numbers and keys/values
def find_and_replace_tokens(description, replacements):
    keys_and_values = list(replacements.keys()) + list(replacements.values())
    if pd.notna(description):
        tokens = description.split()
        new_tokens = []
        for token in tokens:
            replaced = False
            for key_or_value in keys_and_values:
                if (token.startswith(key_or_value) and re.search(r'\d', token[len(key_or_value):])) or \
                   (token.endswith(key_or_value) and re.search(r'\d', token[:len(token)-len(key_or_value)])):
                    # Split numbers and characters with spaces
                    token = re.sub(r'(\d+)', r' \1 ', token)
                    token = re.sub(r'\s+', ' ', token).strip()
                    replaced = True
                    # Print the token that matches the condition
                    print(f"Matched token: {token}")
            new_tokens.append(token if replaced else token)
        return ' '.join(new_tokens)
    return description

# Apply the function to 'tag_description' column to find and replace tokens
data_mapping['tag_description'] = data_mapping['tag_description'].apply(
    lambda x: find_and_replace_tokens(x, initial_replacements) if pd.notna(x) else x
)

# Apply initial replacements
data_mapping['tag_description'] = data_mapping['tag_description'].apply(
    lambda x: ' '.join(replace_tokens_in_list(x.split(), initial_replacements, initial_replacement_counts)) if pd.notna(x) else x
)

# Apply second replacements without re-tokenizing
data_mapping['tag_description'] = data_mapping['tag_description'].apply(
    lambda x: replace_tokens_in_text(x, second_replacements, second_replacement_counts)
)

# Display the counts of each replacement
print("\nInitial Replacement Counts:")
for token, count in initial_replacement_counts.items():
    print(f"{token} replaced {count} times")

print("\nSecond Replacement Counts:")
for token, count in second_replacement_counts.items():
    print(f"{token} replaced {count} times")

# Save the updated data_mapping to a new CSV file (optional)
output_file_path = 'data_mapping_normal.csv'
data_mapping.to_csv(output_file_path, index=False)

print(f"Updated data saved to {output_file_path}")
# Out:
# Matched token: DG 4
# Matched token: DG 4
# Matched token: T/C 1
# Matched token: T/C 1
# Matched token: DG 1
# Matched token: DG 3
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 2
# Matched token: DG 2 B
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 5
# Matched token: DG 3
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: DG 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 3
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: DG 4
# Matched token: DG 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 5
# Matched token: DG 5
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: DG 3
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: DG 3
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: GE 3
# Matched token: DG 3
# Matched token: DG 2 B
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 2 A
# Matched token: DG 2
# Matched token: DG 2 A
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1 -B
# Matched token: TCV- 101
# Matched token: TCV- 301
# Matched token: TCV- 101
# Matched token: TCV- 301
# Matched token: GE 5 /ME
# Matched token: GE 5 /ME
# Matched token: TC 8702 - 1
# Matched token: TC 8702 - 2
# Matched token: TC 8702 - 3
# Matched token: TC 8702 - 4
# Matched token: TC 8702 - 5
# Matched token: TC 8702 - 6
# Matched token: DG 2
# Matched token: DG 3
# Matched token: GE 1
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: TC 1
# Matched token: TC 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: TCV- 105
# Matched token: TCV- 106
# Matched token: GE 2
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 3
# Matched token: DG 5
# Matched token: DG 5
# Matched token: DG 1
# Matched token: 1 G/E
# Matched token: 1 G/E
# Matched token: 1 G/E
# Matched token: 1 G/E
# Matched token: GE 1
# Matched token: GE 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: GE 1
# Matched token: TC 1
# Matched token: TC 2
# Matched token: TC 3
# Matched token: TC 4
# Matched token: TC 1
# Matched token: TC 2
# Matched token: TC 3
# Matched token: TC 4
# Matched token: TC 1
# Matched token: TC 2
# Matched token: TC 3
# Matched token: TC 4
# Matched token: TC 1 -B
# Matched token: TC 2 -B
# Matched token: TC 3 -B
# Matched token: TC 4 -B
# Matched token: TC 1
# Matched token: TC 2
# Matched token: TC 3
# Matched token: TC 4
# Matched token: GE 3
# Matched token: ME 1
# Matched token: ME 2
# Matched token: ME 1
# Matched token: ME 2
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 3
# Matched token: GE 1
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: TC 1
# Matched token: TC 2
# Matched token: TC 3
# Matched token: TC 4
# Matched token: TC 1 -B
# Matched token: TC 2 -B
# Matched token: TC 3 -B
# Matched token: TC 4 -B
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: ME 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 4
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: GE 5
# Matched token: ST 5202 C_T/C
# Matched token: ST 5202 C_T/C
# Matched token: TE 4041 C_T/C
# Matched token: TE 4041 C_T/C
# Matched token: TE 4042 C_T/C
# Matched token: TE 4042 C_T/C
# Matched token: TE 4045 C_SCAVENGE
# Matched token: TE 4046 C_SCAVENGE
# Matched token: FO- 03
# Matched token: FO- 04
# Matched token: FO- 07
# Matched token: FO- 02
# Matched token: FO- 03
# Matched token: FO- 04
# Matched token: FO- 05
# Matched token: FO- 06
# Matched token: FO- 07
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: GEN 3
# Matched token: GEN 3
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 3
# Matched token: GEN 3
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 3
# Matched token: GEN 3
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 3
# Matched token: GEN 3
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 3
# Matched token: GEN 3
# Matched token: GEN 4
# Matched token: GEN 4
# Matched token: GEN 5
# Matched token: GEN 5
# Matched token: T/C 2
# Matched token: T/C 2
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: TC 2
# Matched token: TC 2
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: GE 3
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: TC 1
# Matched token: TC 1 -B
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: ST 5201 C_T/C
# Matched token: ST 5201 C_T/C
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: FO- 02
# Matched token: FO- 05
# Matched token: FO- 06
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: DG 2
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 1
# Matched token: GE 1
# Matched token: TC 1
# Matched token: TC 1
# Matched token: TC 1 -B
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 5
# Matched token: DG 5
# Matched token: DG 5
# Matched token: DG 4
# Matched token: DG 5
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: FO 06
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: DG 2
# Matched token: GE 2
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GEN 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: NO. 1 G/E
# Matched token: NO. 1 G/E
# Matched token: NO. 1 G/E
# Matched token: NO. 1 G/E
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: NO. 2 G/E
# Matched token: NO. 2 G/E
# Matched token: NO. 2 G/E
# Matched token: NO. 2 G/E
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: NO. 3 G/E
# Matched token: NO. 3 G/E
# Matched token: NO. 3 G/E
# Matched token: NO. 3 G/E
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 1
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: DG 1
# Matched token: DG 4
# Matched token: FO 01
# Matched token: DG 2 B
# Matched token: DG 2 B
# Matched token: FO 02
# Matched token: FO 03
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: FO 04
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: FO 05
# Matched token: GE 3
# Matched token: GEN 3
# Matched token: GEN 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: FO 07
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: FO 08
# Matched token: LOAD_ 1
# Matched token: LOAD_ 2
# Matched token: LOAD_ 3
# Matched token: LOAD_ 4
# Matched token: LOAD_ 1
# Matched token: LOAD_ 2
# Matched token: LOAD_ 3
# Matched token: LOAD_ 4
# Matched token: LOAD_ 1
# Matched token: LOAD_ 2
# Matched token: LOAD_ 3
# Matched token: LOAD_ 4
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3 A
# Matched token: DG 3 A
# Matched token: DG 3 A
# Matched token: DG 3 A
# Matched token: DG 3 A
# Matched token: DG 3
# Matched token: DG 3
# Matched token: GE 3 _SUP
# Matched token: DG 3 A
# Matched token: GEN 1
# Matched token: GEN 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: GE 2
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 3
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 1
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: DG 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3
# Matched token: DG 2
# Matched token: DG 2
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: DG 3
# Matched token: DG 3 A
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: DG 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: G/E 2
# Matched token: DG 2
# Matched token: DG 2 A
# Matched token: TCV- 105
# Matched token: TCV- 106
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: GE 1 _COM_ALM
# Matched token: GE 2 _COM_ALM
# Matched token: GE 3 _COM_ALM
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 1
# Matched token: FO- 03 B
# Matched token: FO- 03 B
# Matched token: FO- 03 B
# Matched token: FO- 03 B
# Matched token: FO- 02 B
# Matched token: FO- 02 B
# Matched token: FO- 02 B
# Matched token: FO- 02 B
# Matched token: FO- 01 B
# Matched token: FO- 01 B
# Matched token: FO- 01 B
# Matched token: FO- 01 B
# Matched token: FO- 04 B
# Matched token: FO- 04 B
# Matched token: FO- 04 B
# Matched token: FO- 04 B
# Matched token: FO- 05 B
# Matched token: FO- 05 B
# Matched token: FO- 05 B
# Matched token: FO- 05 B
# Matched token: FO- 06 B
# Matched token: FO- 06 B
# Matched token: FO- 06 B
# Matched token: FO- 06 B
# Matched token: FO- 07 B
# Matched token: FO- 07 B
# Matched token: FO- 07 B
# Matched token: FO- 07 B
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# ...
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 4
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: G/E 5
# Matched token: TE 4041 / 2 C_T/C
# Matched token: TE 4041 / 2 C_T/C
# Matched token: TE 4041 C_T/C
# Matched token: TE 4041 C_T/C
# Matched token: TE 4042 C_T/C
# Matched token: TE 4042 C_T/C
# Matched token: FO- 02
# Matched token: FO- 03
# Matched token: FO- 04
# Matched token: FO- 05
# Matched token: FO- 06
# Matched token: FO- 07
# Matched token: ID_ 02 _GE
# Matched token: ID_ 01 _ME
# Matched token: G_E 1
# Matched token: G_E 2
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: TCS 1
# Matched token: TCS 1
# Matched token: TCS 1
# Matched token: TCS 1
# Matched token: TCS 1
# Matched token: TCS 2
# Matched token: TCS 2
# Matched token: TCS 2
# Matched token: TCS 1
# Matched token: TCS 1
# Matched token: TCS 1
# Matched token: TCS 2
# Matched token: TCS 2
# Matched token: TCS 2
# Matched token: TCS 1
# Matched token: TCS 2
# Matched token: TCS 2
# Matched token: TCS 2
# Matched token: TCS 3
# Matched token: TCS 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 1 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 3 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: 4 MGE
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 1
# Matched token: DG 2 A
# Matched token: DG 2 B
# Matched token: DG 3
# Matched token: TC 8701
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: GE 3
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3
# Matched token: DG 3
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: FO 01
# Matched token: FO 01
# Matched token: FO 01
# Matched token: FO 02
# Matched token: FO 02
# Matched token: FO 02
# Matched token: FO 04
# Matched token: FO 03
# Matched token: FO 03
# Matched token: FO 03
# Matched token: FO 04
# Matched token: FO 04
# Matched token: FO 05
# Matched token: FO 05
# Matched token: FO 05
# Matched token: FO 06
# Matched token: FO 06
# Matched token: FO 06
# Matched token: FO 07
# Matched token: FO 07
# Matched token: FO 07
# Matched token: FO 08
# Matched token: FO 08
# Matched token: FO 08
# Matched token: GE 1 _DEV
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3 A
# Matched token: DG 3 A
# Matched token: DG 3 B
# Matched token: DG 3 B
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 1
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 2
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: DG 3
# Matched token: GE 1 _ 1 _GRP_SUP_TIME
# Matched token: GE 1 _ 1 _GRP_SUP_TIME
# Matched token: GE 1 _DEV_VALUE
# Matched token: GE 1 _DEV_TIMEDELAY
# Matched token: GE 1 _GRP_SUP_TIME
# Matched token: GE 1 _GRP_SUP_TIME
# Matched token: GE 2 _ 1 _GRP_SUP_TIME
# Matched token: GE 2 _ 1 _GRP_SUP_TIME
# Matched token: GE 2 _DEV
# Matched token: GE 2 _DEV_VALUE
# Matched token: GE 2 _DEV_TIMEDELAY
# Matched token: GE 2 _SUP
# Matched token: GE 3 _ 1 _GRP_SUP_TIME
# Matched token: GE 3 _ 1 _GRP_SUP_TIME
# Matched token: GE 3 _DEV
# Matched token: GE 3 _DEV_VALUE
# Matched token: GE 3 _DEV_TIMEDELAY
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: DG 2 A
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: GE 2
# Matched token: 2 MGE
# Matched token: 2 MGE
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 3
# Matched token: DG 3
# Matched token: GE 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: G/E 3
# Matched token: DG 3
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 1
# Matched token: GE 2
# Matched token: GE 1
#
# Initial Replacement Counts:
# MGE replaced 263 times
# GEN replaced 285 times
# GE replaced 1362 times
# G_E replaced 140 times
# ME replaced 573 times
# M_E replaced 136 times
# S_G replaced 27 times
# T_C replaced 9 times
# TC replaced 617 times
# L_O replaced 0 times
# LO replaced 853 times
# F_O replaced 0 times
# FO replaced 762 times
# D_G replaced 0 times
# DG replaced 249 times
#
# Second Replacement Counts:
# _G/E replaced 0 times
# G/E_ replaced 51 times
# _M/E replaced 6 times
# M/E_ replaced 19 times
# _S/G replaced 0 times
# S/G_ replaced 2 times
# _T/C replaced 7 times
# T/C_ replaced 8 times
# _L.O replaced 0 times
# L.O_ replaced 0 times
# _F.O replaced 0 times
# F.O_ replaced 6 times
# _D/G replaced 0 times
# D/G_ replaced 10 times
# Updated data saved to data_mapping_normal.csv
